# %% [markdown]
# https://blog.paperspace.com/train-keras-models-using-genetic-algorithm-with-pygad/

# %%
import pygad.kerasga
import numpy as np
import pandas as pd
import keras as ker
import tensorflow as tf

from sklearn.preprocessing import MinMaxScaler

# Quitar warnings feos
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# %%
#Misma idea que pr1

iris_RAW = pd.read_csv('../Data/iris.data', sep=',')
iris_OG = iris_RAW.copy()
salidas = iris_RAW.pop("class")

# %%
#Misma idea que pr1
entradas = iris_RAW.to_numpy()
mm = MinMaxScaler()
entradas = mm.fit_transform(entradas)

"""
# Categorizamos salidas
label_encoder = LabelEncoder()
salidas = label_encoder.fit_transform(salidas)
"""
salidas = pd.get_dummies(salidas)

# %%
#Misma idea que pr1
def crearMLP(ngenesMLP, tam_entrada,tipo,pesos):

    MLP = ker.Sequential() # Creamos el modelo vacío

    # Añadimos la primera capa (tecnicamente dos, la de entrada (con la variable input_dim) y la oculta)
    MLP.add(ker.layers.Dense(ngenesMLP, input_dim = tam_entrada, activation='relu'))

    # Añadimos la capa de salida
    MLP.add(ker.layers.Dense(3,activation='sigmoid')) 

    # Por último tenemos que configurar el modelo antes de entrenarlo con lo dicho en el enunciado
    # Optimizador: Adam
    # Función error: Mean Squared Error
    # Metricas = Binary accuracy porque nos da el número de precisión de la red
    MLP.compile(optimizer='adam',loss='mean_squared_error',metrics=["accuracy"])

    if(tipo == 1): # Le metemos pesos ya predeterminados
        MLP.set_weights(pesos)

    return MLP

# %%
#Misma idea que pr1
ngenes = 8 # NO TOCAR
model = crearMLP(ngenes,4,0,0)

# %%
#Crea 10 individuos de tipo model
keras_ga = pygad.kerasga.KerasGA(model=model,
                                 num_solutions=50)

# %%
#Funcion de fitness parametros obligatorios el individuo y su index (no se pueden usar mas)
def fitness_func(solution, sol_idx):
    global entradas, salidas, keras_ga, model #Uso la varables globales para no parametrizar

    # Devuelve los pesos de la solucion (individuo) enbase a model es decir camvia un 1D vector que usa pygad a una matriz de pesos tipo model
    model_weights_matrix = pygad.kerasga.model_weights_as_matrix(model=model,
                                                                weights_vector=solution) 
    model.set_weights(weights=model_weights_matrix) # Adjuntamos los pesos al model para poder evaluarlo

    solution_fitness = model.evaluate(entradas, salidas,verbose=0)[1] #evaluamos usando solo usamos el accuracy

    return solution_fitness # devolvemos

# %%
def callback_generation(ga_instance):
    print("Generation = {generation}".format(generation=ga_instance.generations_completed))
    print("Fitness    = {fitness}".format(fitness=ga_instance.best_solution()[1]))

# %%
num_generations = 100
num_parents_mating = 25
probabilidad_mutacion = 0.05
initial_population = keras_ga.population_weights

ga_instance = pygad.GA(num_generations=num_generations, 
                       num_parents_mating=num_parents_mating, 
                       initial_population=initial_population,
                       mutation_probability = probabilidad_mutacion,
                       parent_selection_type="rws", #ruleta
                       crossover_type = None,
                       fitness_func=fitness_func,
                       on_generation=callback_generation)

# %%
ga_instance.run()
# Out:
# Generation = 1
# Fitness    = 0.6666666865348816
# Generation = 2
# Fitness    = 0.6666666865348816
# Generation = 3
# Fitness    = 0.6666666865348816
# Generation = 4
# Fitness    = 0.6666666865348816
# Generation = 5
# Fitness    = 0.6666666865348816
# Generation = 6
# Fitness    = 0.6666666865348816
# Generation = 7
# Fitness    = 0.6666666865348816
# Generation = 8
# Fitness    = 0.6666666865348816
# Generation = 9
# Fitness    = 0.6666666865348816
# Generation = 10
# Fitness    = 0.6600000262260437
# Generation = 11
# Fitness    = 0.6666666865348816
# Generation = 12
# Fitness    = 0.6666666865348816
# Generation = 13
# Fitness    = 0.7066666483879089
# Generation = 14
# Fitness    = 0.7066666483879089
# Generation = 15
# Fitness    = 0.7066666483879089
# Generation = 16
# Fitness    = 0.7066666483879089
# Generation = 17
# Fitness    = 0.7066666483879089
# Generation = 18
# Fitness    = 0.7333333492279053
# Generation = 19
# Fitness    = 0.753333330154419
# Generation = 20
# Fitness    = 0.7333333492279053
# Generation = 21
# Fitness    = 0.7333333492279053
# Generation = 22
# Fitness    = 0.7066666483879089
# Generation = 23
# Fitness    = 0.8866666555404663
# Generation = 24
# Fitness    = 0.8866666555404663
# Generation = 25
# Fitness    = 0.8866666555404663
# Generation = 26
# Fitness    = 0.7200000286102295
# Generation = 27
# Fitness    = 0.8266666531562805
# Generation = 28
# Fitness    = 0.8266666531562805
# Generation = 29
# Fitness    = 0.8266666531562805
# Generation = 30
# Fitness    = 0.8933333158493042
# Generation = 31
# Fitness    = 0.8266666531562805
# Generation = 32
# Fitness    = 0.8266666531562805
# Generation = 33
# Fitness    = 0.9066666960716248
# Generation = 34
# Fitness    = 0.8866666555404663
# Generation = 35
# Fitness    = 0.8266666531562805
# Generation = 36
# Fitness    = 0.8266666531562805
# Generation = 37
# Fitness    = 0.846666693687439
# Generation = 38
# Fitness    = 0.8199999928474426
# Generation = 39
# Fitness    = 0.8533333539962769
# Generation = 40
# Fitness    = 0.8533333539962769
# Generation = 41
# Fitness    = 0.8933333158493042
# Generation = 42
# Fitness    = 0.8799999952316284
# Generation = 43
# Fitness    = 0.8666666746139526
# Generation = 44
# Fitness    = 0.9133333563804626
# Generation = 45
# Fitness    = 0.800000011920929
# Generation = 46
# Fitness    = 0.800000011920929
# Generation = 47
# Fitness    = 0.800000011920929
# Generation = 48
# Fitness    = 0.7799999713897705
# Generation = 49
# Fitness    = 0.7799999713897705
# Generation = 50
# Fitness    = 0.7799999713897705
# Generation = 51
# Fitness    = 0.7933333516120911
# Generation = 52
# Fitness    = 0.8399999737739563
# Generation = 53
# Fitness    = 0.8399999737739563
# Generation = 54
# Fitness    = 0.8866666555404663
# Generation = 55
# Fitness    = 0.8866666555404663
# Generation = 56
# Fitness    = 0.8866666555404663
# Generation = 57
# Fitness    = 0.8066666722297668
# Generation = 58
# Fitness    = 0.8066666722297668
# Generation = 59
# Fitness    = 0.8199999928474426
# Generation = 60
# Fitness    = 0.8199999928474426
# Generation = 61
# Fitness    = 0.8199999928474426
# Generation = 62
# Fitness    = 0.8266666531562805
# Generation = 63
# Fitness    = 0.753333330154419
# Generation = 64
# Fitness    = 0.753333330154419
# Generation = 65
# Fitness    = 0.8799999952316284
# Generation = 66
# Fitness    = 0.8799999952316284
# Generation = 67
# Fitness    = 0.8799999952316284
# Generation = 68
# Fitness    = 0.746666669845581
# Generation = 69
# Fitness    = 0.746666669845581
# Generation = 70
# Fitness    = 0.746666669845581
# Generation = 71
# Fitness    = 0.7733333110809326
# Generation = 72
# Fitness    = 0.746666669845581
# Generation = 73
# Fitness    = 0.746666669845581
# Generation = 74
# Fitness    = 0.746666669845581
# Generation = 75
# Fitness    = 0.8600000143051147
# Generation = 76
# Fitness    = 0.8600000143051147
# Generation = 77
# Fitness    = 0.8600000143051147
# Generation = 78
# Fitness    = 0.746666669845581
# Generation = 79
# Fitness    = 0.7866666913032532
# Generation = 80
# Fitness    = 0.746666669845581
# Generation = 81
# Fitness    = 0.746666669845581
# Generation = 82
# Fitness    = 0.746666669845581
# Generation = 83
# Fitness    = 0.6666666865348816
# Generation = 84
# Fitness    = 0.6666666865348816
# Generation = 85
# Fitness    = 0.6666666865348816
# Generation = 86
# Fitness    = 0.6666666865348816
# Generation = 87
# Fitness    = 0.6666666865348816
# Generation = 88
# Fitness    = 0.6666666865348816
# Generation = 89
# Fitness    = 0.6666666865348816
# Generation = 90
# Fitness    = 0.6800000071525574
# Generation = 91
# Fitness    = 0.6666666865348816
# Generation = 92
# Fitness    = 0.6666666865348816
# Generation = 93
# Fitness    = 0.6666666865348816
# Generation = 94
# Fitness    = 0.6666666865348816
# Generation = 95
# Fitness    = 0.6666666865348816
# Generation = 96
# Fitness    = 0.6733333468437195
# Generation = 97
# Fitness    = 0.8600000143051147
# Generation = 98
# Fitness    = 0.8600000143051147
# Generation = 99
# Fitness    = 0.6666666865348816
# Generation = 100
# Fitness    = 0.7200000286102295

# %%
ga_instance.plot_fitness()
